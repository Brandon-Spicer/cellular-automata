# %% [markdown]
# ### Scrape Mirek Wojtowicz's site for rules

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
try:
    import cPickle as pickle
except:
    import pickle

# %%
url = 'http://www.mirekw.com/ca/rullex_gene.html'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
table = soup.findChildren('table')[1]

# %%
rows = table.findChildren('tr')

# %%
rows[0]
# Out:
# <tr>
# <td width="14%"><strong>Name</strong></td>
# <td width="14%"><strong>Rule (S/B/C)</strong></td>
# <td width="12%"><strong>Character</strong></td>
# <td width="59%"><strong>Description</strong></td>
# </tr>

# %%
names = []
rules = []
characters = []
descriptions = []
for row in rows:
    columns = row.findChildren('td')
    names.append(columns[0].text)
    rules.append(columns[1].text)
    characters.append(columns[2].text)
    descriptions.append(columns[3].text)
for i in range(len(names)):
    names[i] = names[i].replace('\r\n', '')
    names[i] = names[i].replace('   ', '')

# %%
df = pd.DataFrame([names, rules, characters, descriptions]).T

# %%
df.columns = df.iloc[0]

# %%
df = df.iloc[1:]

# %%
df.index = pd.RangeIndex(start=0, stop=44)

# %%
df.rename(columns={'Rule (S/B/C)':'Rule'}, inplace=True)

# %%
df
# Out:
# 0               Name             Rule  Character  \
# 0            Banners      2367/3457/5  Exploding
# 1            BelZhab          23/23/8  Exploding
# 2   BelZhab Sediment      145678/23/8  Exploding
# 3         Bloomerang     234/34678/24  Expanding
# 4            Bombers        345/24/25    Chaotic
# 5            Brain 6          6/246/3    Chaotic
# 6      Brian's Brain             /2/3    Chaotic
# 7              Burst   0235678/3468/9    Chaotic
# 8            BurstII    235678/3468/9    Chaotic
# 9       Caterpillars     124567/378/4    Chaotic
# 10          Chenille    05678/24567/6  Exploding
# 11   Circuit Genesis      2345/1234/8  Expanding
# 12           Cooties           23/2/8  Exploding
# 13          Ebb&Flow     012478/36/18  Exploding
# 14       Ebb&Flow II     012468/37/18  Exploding
# 15            Faders           2/2/25  Exploding
# 16         Fireworks          2/13/21  Exploding
# 17  Flaming Starbows         347/23/8  Exploding
# 18             Frogs          12/34/3    Chaotic
# 19    Frozen spirals         356/23/6     Cyclic
# 20        Glisserati  035678/245678/7  Exploding
# 21         Glissergy  035678/245678/5  Exploding
# 22              Lava    12345/45678/8  Expanding
# 23             Lines     012345/458/3     Stable
# 24  LivingOn TheEdge          345/3/6    Chaotic
# 25       Meteor Guns     01245678/3/8  Expanding
# 26              Nova    45678/2478/25  Expanding
# 27           OrthoGo            3/2/4  Exploding
# 28   Prairie on fire         345/34/6  Exploding
# 29           RainZha           2/23/8  Exploding
# 30              Rake      3467/2678/6  Exploding
# 31        SediMental    45678/25678/4  Exploding
# 32             Snake       03467/25/6  Exploding
# 33        SoftFreeze       13458/38/6    Chaotic
# 34           Spirals          2/234/5  Exploding
# 35         Star Wars          345/2/4  Exploding
# 36            Sticks         3456/2/6  Exploding
# 37             Swirl          23/34/8    Chaotic
# 38       ThrillGrill       1234/34/48  Expanding
# 39          Transers         345/26/5  Exploding
# 40        TransersII        0345/26/6  Exploding
# 41         Wanderers      345/34678/5  Exploding
# 42             Worms        3467/25/6  Exploding
# 43             Xtasy     1456/2356/16  Exploding
#
# 0                                         Description
# 0   The rule often produces ships with growing flu...
# 1   Another case of Zhabotinsky reaction.\r\n    A...
# 2   The rule creates  BelZhab like patterns that h...
# 3   A wave rule that rebounds into a kinder, gentl...
# 4   A close variant of  StarWars rule with much mo...
# 5   An interesting variation of immortal  Brian's\...
# 6   Brian's Brain (BB, Brain), unquestionably one ...
# 7   A generations rule related to Nova, Prairie Fi...
# 8   Basically it is Burst without the single cell ...
# 9   The name comes from very commonly occurring ca...
# 10                                    Author unknown.
# 11  Circuitry which evolves far beyond its program...
# 12  A very vivacious rule, with cells crawling aro...
# 13  A slow exploding rule with interesting interna...
# 14  A close variant of Ebb&Flow that supports simp...
# 15  A "genetic" cross between Life and Brian's Bra...
# 16  Nearly perfect fireworks simulation. It produc...
# 17  In this world beautiful expanding diamonds and...
# 18  The name comes from very commonly occurring fr...
# 19  The rule features a popular Zhabotinsky reacti...
# 20  "From simple seeds this rule is often highly\r...
# 21  "This rule differs from Glisserati only in its...
# 22  All patterns are getting very slowly filled wi...
# 23  The rule quickly self-organizes into linear st...
# 24  LOTE. In this very chaotic rule it's hard to t...
# 25  Almost any design above a certain level of com...
# 26  Very lovely rule characterized by vibrant yet ...
# 27  This simple rule supports spontaneous orthogon...
# 28  This rule covers the lattice with fire. For be...
# 29  The simplest "Zhabotinsky" style cellular auto...
# 30  This rule is a simple variation of the  Worms ...
# 31  From a random seed state of 30% ones, the rule...
# 32  This rule is a simple variation of the  Worms\...
# 33  "The rule is delicately poised between "solid"...
# 34  The rule produces beautiful stable spirals tha...
# 35  A very interesting and beautiful rule producin...
# 36  This interesting rule builds a variety of stic...
# 37  While spirals are common in CAs (see for examp...
# 38  Sparkling dynamics inhabit and rearrange a gri...
# 39  A beautiful and dynamic rule with many distinc...
# 40                          A rule by Michael Sweney.
# 41  A rule very similar to "Prairie on fire", but ...
# 42  A very vigorous rule producing crowds of disgu...
# 43  From simple seeds in a closed universe this is...

# %%
with open('rules.pickle', 'wb') as pickle_out:
    pickle.dump(df, pickle_out)
